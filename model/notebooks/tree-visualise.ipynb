# %% [markdown]
# # Minh họa Decision Tree
#
# Phần này sẽ dùng sklearn.tree.export_text để in ra cây quyết định

# %%
# sklearn.tree.plot_tree vẽ cây
from sklearn import tree

 # Export bộ luật
from sklearn.tree import export_text
import pickle as pkl
import matplotlib.pyplot as plt

# %%
__MODEL__ = '../model/'

# %% [markdown]
# Load model và vectorizer (chủ yếu là cần bộ features)

# %%
with open(__MODEL__ + 'vectorizer.pkl', 'rb+') as f:
    vectorizer = pkl.load(f)

with open(__MODEL__ + 'decision_tree.pkl', 'rb+') as f:
    decision_model = pkl.load(f)

# %% [markdown]
# In bộ luật:

# %%
tree_rules = export_text(decision_model, feature_names = vectorizer.get_feature_names())
# Out:
# d:\Software\Python\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
print(tree_rules)
# Out:
# |--- reuters <= 0.01
# |   |--- federated <= 0.01
# |   |   |--- nov <= 0.02
# |   |   |   |--- ifr <= 0.06
# |   |   |   |   |--- parliament <= 0.05
# |   |   |   |   |   |--- reuters <= 0.00
# |   |   |   |   |   |   |--- offset <= 0.04
# |   |   |   |   |   |   |   |--- pyongyang <= 0.14
# |   |   |   |   |   |   |   |   |--- scorched <= 0.02
# |   |   |   |   |   |   |   |   |   |--- provide <= 0.09
# |   |   |   |   |   |   |   |   |   |   |--- region <= 0.07
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 110
# |   |   |   |   |   |   |   |   |   |   |--- region >  0.07
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- provide >  0.09
# |   |   |   |   |   |   |   |   |   |   |--- action <= 0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- action >  0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# ...

# %% [markdown]
# Vẽ ra luôn!

# %%
tree.plot_tree(decision_model)
plt.title("Decision Tree trained with Fake News dataset")
plt.plot()
# Out:
# []
